# %%
import pandas as pd

# %%
leb_data = pd.read_csv('../pro-test/data/Leb-gp.csv',index_col=0,header=1)

# %%
leb_data = leb_data.drop(columns=['coderinitials','datecoded', 'narrative','Unnamed: 7','endsize','sizetext',
                      'articledate1', 'sourcename1', 'articletitle1', 'pagenum1', 'URL1',
       'DB1', 'sourcename2', 'articletitle2', 'articledate2', 'pagenum2',
       'URL2', 'DB2', 'sourcename3', 'articletitle3', 'articledate3',
       'pagenum3', 'URL3', 'DB3'])

# %%
iraq_data = pd.read_csv('../pro-test/data/Iraq-gp.csv',index_col=0,header=0)

# %%
iraq_data = iraq_data.drop(columns=['coderinitials','datecoded', 'narrative','endsize','sizetext',
                      'responsetext', 'sourcename1', 'articletitle1', 'articledate1',
       'pagenum1', 'URL1', 'DB1', 'sourcename2', 'articletitle2',
       'articledate2', 'pagenum2', 'URL2', 'DB2', 'sourcename3',
       'articletitle3', 'articledate3', 'pagenum3', 'URL3', 'DB3', 'counts'])

# %%
egypt_data = pd.read_csv('../pro-test/data/Egypt-gp.csv',index_col=1,header=0)

# %%
egypt_data = egypt_data.drop(columns=['neweventid','coderinitials','datecoded', 'narrative','endsize',
                                      'govcampas', 'disarcapmas', 'admin2Pcode','sizetext',
                      'sourcename1', 'articletitle1', 'articledate1', 'pagenum1', 'URL1',
       'DB1', 'sourcename2', 'articletitle2', 'articledate2', 'pagenum2',
       'URL2', 'DB2', 'sourcename3', 'articletitle3', 'articledate3',
       'pagenum3', 'URL3', 'DB3'])

# %%
leb_data.to_csv('../pro-test/data/Leb_1_drop_non_impact_params.csv', index=True)

# %%
iraq_data.to_csv('../pro-test/data/iraq_1_drop_non_impact_params.csv', index=True)

# %%
egypt_data.to_csv('../pro-test/data/egypt_1_drop_non_impact_params.csv', index=True)

# %%
pd.read_csv('../pro-test/data/Leb_1_drop_non_impact_params.csv', index_col=0)
# Out:
#                     nameofevent   startdate      endate  ongoing  \
# recordnumber
# 20191592                 Thawra  2019-11-26  2019-11-26        0
# 20200162                 Thawra  2020-01-13  2020-01-13        0
# 20191864      Al Asir detainees  2019-12-06  2019-12-06        0
# 20200903                 Thawra  2020-03-27  2020-03-27        0
# 20200891                 Thawra  2020-03-20  2020-03-20        0
# ...                         ...         ...         ...      ...
# 20200311                 Thawra  2020-01-16  2020-01-16        0
# 20192258                 Thawra  2019-12-24  2019-12-24        0
# 20191013                 Thawra  2019-11-10  2019-11-10        0
# 20200552                 Thawra  2020-02-02  2020-02-02        0
# 20191011                 Thawra  2019-11-10  2019-11-10        0
#
#              timeofprotest      governorate   district  \
# recordnumber
# 20191592                 0           Beirut     Beirut
# ...
