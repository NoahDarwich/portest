# %%
import pandas as pd

# %%
df = pd.read_csv('../api/the_features.csv')
df.drop(columns='combined_sizes', inplace=True)

# %%
df['country'] = df['country'].drop_duplicates()
df['governorate'] = df['governorate'].drop_duplicates().dropna()
df['locationtypeend'] = df['locationtypeend'].drop_duplicates().dropna()
df['demandtypeone'] = df['demandtypeone'].drop_duplicates().dropna()
df['tacticprimary'] = df['tacticprimary'].drop_duplicates().dropna()
df['violence'] = df['violence'].drop_duplicates().dropna()

# %%
df.dropna(how='all', inplace=True)

# %%
# df.to_csv('../frontend/data/')
