# %% [markdown]
# # Imports

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Input Data

# %%
df = pd.read_csv('../pro-test/data/Leb_1_drop_non_impact_params.csv',index_col=0,header=0)

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## X Parameters

# %%
selected_X_parameters = ['Amal','Army present at event','Arrests / detentions','Hezbollah','Injuries inflicted','Party Militias/ Baltagia present at event','Progressive Socialist Movement','Security forces present at event','sizeexact']
selected_X_parameters
# Out:
# ['Amal',
#  'Army present at event',
#  'Arrests / detentions',
#  'Hezbollah',
#  'Injuries inflicted',
#  'Party Militias/ Baltagia present at event',
#  'Progressive Socialist Movement',
#  'Security forces present at event',
#  'sizeexact']

# %% [markdown]
# ## y Parameters

# %%
y = pd.get_dummies(df['repression'])
y
# Out:
#               Army present at event  Arrests / detentions  Deaths inflicted  \
# recordnumber
# 20191592                          0                     0                 0
# 20200162                          0                     0                 0
# 20191864                          0                     0                 0
# 20200903                          0                     0                 0
# 20200891                          0                     0                 0
# ...                             ...                   ...               ...
# 20200311                          0                     0                 0
# 20192258                          1                     0                 0
# 20191013                          0                     0                 0
# 20200552                          0                     0                 0
# 20191011                          0                     0                 0
#
# ...

# %%
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_column)
len(y[0])
# Out:
# 8
