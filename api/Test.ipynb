# %%
import pandas as pd
import joblib
#from sklearn.preprocessing import OrdinalEncoder

# %%
load_path_model = "final_RF_model"
load_path_pre_processor = "pipeline"

# Country = "Iraq"
# Governorate = "Missan"
# Location_Type = "Company offices"
# Demand_Type = "Labor"
# Protest_Tactic = "Demonstration / protest"
# Protestor_Violence = "None"
# Size_of_Event = 100

pipeline = joblib.load(load_path_pre_processor)
model = joblib.load(load_path_model)

# prediction_string = [[
#     Country, Governorate, Location_Type, Demand_Type, Protest_Tactic,
#     Protestor_Violence, Size_of_Event
# ]]

#prediction = str(joblib.load(load_path).predict(prediction_string)[0])
#prediction

# %%
parameters = {'country':"Iraq",
              'Governorate':"Missan",
              'Location_Type':"Company offices",
              'Demand_Type':"Labor",
              'Tactic_Primary':"Demonstration / protest",
              'Violence_Protesters':"None",
              'Number_of_Participants':100}

# %%
def get_prediction(parameters):

    model = joblib.load('final_RF_model')
    pipeline = joblib.load('pipeline')


    # parameters = dict(country= kwargs['country'],
    #               governorate= kwargs['Governorate'],
    #               location_type= kwargs['Location_Type'],
    #               demand_type= kwargs['Demand_Type'],
    #               protest_tactic= kwargs['Tactic_Primary'],
    #               protestor_violence= kwargs['Violence_Protesters'],
    #               combined_sizes=kwargs['Number_of_Participants'])

    X = pd.DataFrame({'country':parameters['country'],
                      'governorate':parameters['Governorate'],
                      'locationtypeend':parameters['Location_Type'],
                           'demandtypeone':parameters['Demand_Type'],
                           'tacticprimary':parameters['Tactic_Primary'],
                           'violence':parameters['Violence_Protesters'],
                          'combined_sizes':parameters['Number_of_Participants']},index=[0])
    X_transformed = pipeline.transform(X)

    return X_transformed

# %%
get_prediction(parameters)
# Out:
# /home/noahdarwich/.pyenv/versions/lewagon/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.22 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/noahdarwich/.pyenv/versions/lewagon/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.22 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
# X_test_new = pd.DataFrame({'country':['Iraq'],'governorate':['Baghdad'], 'locationtypeend':['Midan'],
#                            'demandtypeone':['Politics (national)'],
#                            'tacticprimary':['Demonstration / protest'],
#                            'violence':['Riot'],
#                           'combined_sizes': [3001]})

# X_test_new_2 = pd.DataFrame({'country':['Egypt'],'governorate':['Cairo'], 'locationtypeend':['Midan'],
#                            'demandtypeone':['Politics (national)'],
#                            'tacticprimary':['Demonstration / protest'],
#                            'violence':['Riot'],
#                           'combined_sizes': [3001]})
# X_test_new_2 = pipeline.transform(X_test_new_2)

# X_test_new = pipeline.transform(X_test_new)

# %%
# model.predict_proba(X_test_new_2)
